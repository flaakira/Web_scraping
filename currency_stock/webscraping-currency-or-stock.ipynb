# %%
import pandas as pd
from pandas_datareader import data as web
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# # Period Analyses

# %%
start = dt.datetime(2018,1,1)
end = dt.datetime.today()

# %% [markdown]
# ## Cervus Stock

# %%
stock_cerv = web.DataReader('cerv.to','yahoo', start, end).reset_index()

# %%
stock_cerv.tail()
# Out:
#           Date       High        Low       Open      Close    Volume  \
# 913 2021-08-20  19.299999  19.260000  19.260000  19.270000   36500.0
# 914 2021-08-23  19.340000  19.260000  19.290001  19.320000   38300.0
# 915 2021-08-24  19.320000  19.260000  19.280001  19.290001  158700.0
# 916 2021-08-25  19.340000  19.270000  19.299999  19.270000  265100.0
# 917 2021-08-26  19.330000  19.290001  19.299999  19.320000   38976.0
#
#      Adj Close
# 913  19.270000
# 914  19.320000
# 915  19.290001
# 916  19.270000
# 917  19.320000

# %%
plt.figure(figsize=(18,8))
plt.plot(stock_cerv['Date'], stock_cerv['Open'], color = 'r')
plt.plot(stock_cerv['Date'], stock_cerv['Close'], color = 'b')
plt.plot(stock_cerv['Date'], stock_cerv['High'], color = 'y')
plt.plot(stock_cerv['Date'], stock_cerv['Low'], color = 'g')
plt.title('Cervus Equipment Corporation (CERV.TO)')
plt.show()

# %% [markdown]
# ## Petrobras Stock

# %%
stock_pbr = web.DataReader('PBR','yahoo', start, end).reset_index()

# %%
stock_pbr.tail()
# Out:
#           Date    High    Low   Open  Close      Volume  Adj Close
# 915 2021-08-20  10.120   9.76   9.82  10.10  27656100.0      10.10
# 916 2021-08-23  10.460  10.21  10.24  10.42  29732100.0      10.42
# 917 2021-08-24  10.810  10.52  10.55  10.80  14495600.0      10.80
# 918 2021-08-25  10.930  10.68  10.77  10.89  14737200.0      10.89
# 919 2021-08-26  10.955  10.74  10.90  10.74  14032048.0      10.74

# %%
plt.figure(figsize=(18,8))
plt.plot(stock_pbr['Date'], stock_pbr['Open'], color = 'r')
plt.plot(stock_pbr['Date'], stock_pbr['Close'], color = 'b')
plt.plot(stock_pbr['Date'], stock_pbr['High'], color = 'y')
plt.plot(stock_pbr['Date'], stock_pbr['Low'], color = 'g')
plt.title('Petrobras (PBR)')
plt.show()

# %% [markdown]
# ## Apple Stocks

# %%
stock_aapl = web.DataReader('AAPL','yahoo', start, end).reset_index()

# %%
stock_pbr.tail()
# Out:
#           Date    High    Low   Open  Close      Volume  Adj Close
# 915 2021-08-20  10.120   9.76   9.82  10.10  27656100.0      10.10
# 916 2021-08-23  10.460  10.21  10.24  10.42  29732100.0      10.42
# 917 2021-08-24  10.810  10.52  10.55  10.80  14495600.0      10.80
# 918 2021-08-25  10.930  10.68  10.77  10.89  14737200.0      10.89
# 919 2021-08-26  10.955  10.74  10.90  10.74  14032048.0      10.74

# %%
plt.figure(figsize=(18,8))
plt.plot(stock_aapl['Date'], stock_aapl['Open'], color = 'r')
plt.plot(stock_aapl['Date'], stock_aapl['Close'], color = 'b')
plt.plot(stock_aapl['Date'], stock_aapl['High'], color = 'y')
plt.plot(stock_aapl['Date'], stock_aapl['Low'], color = 'g')
plt.title('Apple Inc. (AAPL)')
plt.show()

# %% [markdown]
# ## Currency CAD to US dolar

# %%
currency_CADUSD = web.DataReader('CAD=X','yahoo', start, end).reset_index()

# %%
currency_CADUSD.tail()
# Out:
#           Date     High      Low     Open    Close  Volume  Adj Close
# 928 2021-08-19  1.29476  1.28130  1.28286  1.28313     0.0    1.28313
# 929 2021-08-22  1.28213  1.26612  1.28206  1.28260     0.0    1.28260
# 930 2021-08-23  1.26575  1.25794  1.26522  1.26510     0.0    1.26510
# 931 2021-08-24  1.26401  1.25870  1.25931  1.25960     0.0    1.25960
# 932 2021-08-26  1.26940  1.25820  1.25886  1.26937     0.0    1.26937

# %%
plt.figure(figsize=(18,8))
plt.plot(currency_CADUSD['Date'], currency_CADUSD['Open'], color = 'r')
plt.plot(currency_CADUSD['Date'], currency_CADUSD['Close'], color = 'b')
plt.plot(currency_CADUSD['Date'], currency_CADUSD['High'], color = 'y')
plt.plot(currency_CADUSD['Date'], currency_CADUSD['Low'], color = 'g')
plt.title('USD/CAD (CAD=X)')
plt.show()

# %% [markdown]
# ## Currency Real- Brazil to US Dolar

# %%
currency_BRLUSD = web.DataReader('BRL=X','yahoo', start, end).reset_index()

# %%
currency_BRLUSD.tail()
# Out:
#           Date    High     Low      Open   Close  Volume  Adj Close
# 928 2021-08-19  5.4718  5.3400  5.414300  5.4141     0.0     5.4141
# 929 2021-08-22  5.4043  5.3390  5.384409  5.3790     0.0     5.3790
# 930 2021-08-23  5.3814  5.2563  5.380100  5.3799     0.0     5.3799
# 931 2021-08-24  5.2667  5.2263  5.245900  5.2458     0.0     5.2458
# 932 2021-08-26  5.2667  5.1937  5.208600  5.2643     0.0     5.2643

# %%
plt.figure(figsize=(18,8))
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['Open'], color = 'r')
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['Close'], color = 'b')
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['High'], color = 'y')
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['Low'], color = 'g')
plt.title('USD/BRL (BRL=X)')
plt.show()
