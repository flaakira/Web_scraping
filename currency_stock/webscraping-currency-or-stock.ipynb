# %%
import pandas as pd
from pandas_datareader import data as web
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# # Period Analyses

# %%
start = dt.datetime(2020,4,1)
end = dt.datetime.today()

# %% [markdown]
# ## Cervus Stock

# %%
stock_cerv = web.DataReader('cerv.to','yahoo', start, end).reset_index()

# %%
stock_cerv.tail()
# Out:
#           Date       High        Low       Open      Close    Volume  \
# 348 2021-08-20  19.299999  19.260000  19.260000  19.270000   36500.0
# 349 2021-08-23  19.340000  19.260000  19.290001  19.320000   38300.0
# 350 2021-08-24  19.320000  19.260000  19.280001  19.290001  158700.0
# 351 2021-08-25  19.340000  19.270000  19.299999  19.270000  265100.0
# 352 2021-08-26  19.330000  19.290001  19.299999  19.299999   55976.0
#
#      Adj Close
# 348  19.270000
# 349  19.320000
# 350  19.290001
# 351  19.270000
# 352  19.299999

# %%
plt.figure(figsize=(18,8))
plt.plot(stock_cerv['Date'], stock_cerv['Open'], color = 'r', label='Open')
plt.plot(stock_cerv['Date'], stock_cerv['Close'], color = 'b',label='Close')
plt.plot(stock_cerv['Date'], stock_cerv['High'], color = 'y',label='High')
plt.plot(stock_cerv['Date'], stock_cerv['Low'], color = 'g',label='Low')
plt.title('Cervus Equipment Corporation (CERV.TO)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Petrobras Stock

# %%
stock_pbr = web.DataReader('PBR','yahoo', start, end).reset_index()

# %%
stock_pbr.tail()
# Out:
#           Date    High    Low   Open  Close      Volume  Adj Close
# 350 2021-08-20  10.120   9.76   9.82  10.10  27656100.0      10.10
# 351 2021-08-23  10.460  10.21  10.24  10.42  29732100.0      10.42
# 352 2021-08-24  10.810  10.52  10.55  10.80  14495600.0      10.80
# 353 2021-08-25  10.930  10.68  10.77  10.89  14737200.0      10.89
# 354 2021-08-26  10.955  10.74  10.90  10.77  15428793.0      10.77

# %%
plt.figure(figsize=(18,8))
plt.plot(stock_pbr['Date'], stock_pbr['Open'], color = 'r', label='Open')
plt.plot(stock_pbr['Date'], stock_pbr['Close'], color = 'b',label='Close')
plt.plot(stock_pbr['Date'], stock_pbr['High'], color = 'y',label='High')
plt.plot(stock_pbr['Date'], stock_pbr['Low'], color = 'g',label='Low')
plt.title('Petrobras (PBR)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Apple Stocks

# %%
stock_aapl = web.DataReader('AAPL','yahoo', start, end).reset_index()

# %%
stock_pbr.tail()
# Out:
#           Date    High    Low   Open  Close      Volume  Adj Close
# 350 2021-08-20  10.120   9.76   9.82  10.10  27656100.0      10.10
# 351 2021-08-23  10.460  10.21  10.24  10.42  29732100.0      10.42
# 352 2021-08-24  10.810  10.52  10.55  10.80  14495600.0      10.80
# 353 2021-08-25  10.930  10.68  10.77  10.89  14737200.0      10.89
# 354 2021-08-26  10.955  10.74  10.90  10.77  15428793.0      10.77

# %%
plt.figure(figsize=(18,8))
plt.plot(stock_aapl['Date'], stock_aapl['Open'], color = 'r', label='Open')
plt.plot(stock_aapl['Date'], stock_aapl['Close'], color = 'b',label='Close')
plt.plot(stock_aapl['Date'], stock_aapl['High'], color = 'y',label='High')
plt.plot(stock_aapl['Date'], stock_aapl['Low'], color = 'g',label='Low')
plt.title('Apple Inc. (AAPL)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Currency CAD to US dolar

# %%
currency_CADUSD = web.DataReader('CAD=X','yahoo', start, end).reset_index()

# %%
currency_CADUSD.tail()
# Out:
#           Date     High      Low     Open    Close  Volume  Adj Close
# 362 2021-08-19  1.29476  1.28130  1.28286  1.28313       0    1.28313
# 363 2021-08-22  1.28213  1.26612  1.28206  1.28260       0    1.28260
# 364 2021-08-23  1.26575  1.25794  1.26522  1.26510       0    1.26510
# 365 2021-08-24  1.26401  1.25870  1.25931  1.25960       0    1.25960
# 366 2021-08-26  1.26954  1.25820  1.25886  1.26830       0    1.26830

# %%
plt.figure(figsize=(18,8))
plt.plot(currency_CADUSD['Date'], currency_CADUSD['Open'], color = 'r', label='Open')
plt.plot(currency_CADUSD['Date'], currency_CADUSD['Close'], color = 'b',label='Close')
plt.plot(currency_CADUSD['Date'], currency_CADUSD['High'], color = 'y',label='High')
plt.plot(currency_CADUSD['Date'], currency_CADUSD['Low'], color = 'g',label='Low')
plt.title('USD/CAD (CAD=X)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Currency Real- Brazil to US Dolar

# %%
currency_BRLUSD = web.DataReader('BRL=X','yahoo', start, end).reset_index()

# %%
currency_BRLUSD.tail()
# Out:
#           Date    High     Low      Open   Close  Volume  Adj Close
# 362 2021-08-19  5.4718  5.3400  5.414300  5.4141       0     5.4141
# 363 2021-08-22  5.4043  5.3390  5.384409  5.3790       0     5.3790
# 364 2021-08-23  5.3814  5.2563  5.380100  5.3799       0     5.3799
# 365 2021-08-24  5.2667  5.2263  5.245900  5.2458       0     5.2458
# 366 2021-08-26  5.2667  5.1937  5.208600  5.2515       0     5.2515

# %%
plt.figure(figsize=(18,8))
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['Open'], color = 'r', label='Open')
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['Close'], color = 'b',label='Close')
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['High'], color = 'y',label='High')
plt.plot(currency_BRLUSD['Date'], currency_BRLUSD['Low'], color = 'g',label='Low')
plt.title('USD/BRL (BRL=X)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Index - SP 500

# %%
index_SP500 = web.DataReader('^GSPC','yahoo', start, end).reset_index()

# %%
index_SP500.tail()
# Out:
#           Date         High          Low         Open        Close  \
# 350 2021-08-20  4444.350098  4406.799805  4410.560059  4441.669922
# 351 2021-08-23  4489.879883  4450.290039  4450.290039  4479.529785
# 352 2021-08-24  4492.810059  4482.279785  4484.399902  4486.229980
# 353 2021-08-25  4501.709961  4485.660156  4490.450195  4496.189941
# 354 2021-08-26  4495.899902  4468.990234  4493.750000  4471.479980
#
#          Volume    Adj Close
# 350  2867770000  4441.669922
# 351  2965520000  4479.529785
# 352  3037770000  4486.229980
# 353  2554680000  4496.189941
# 354  1419090000  4471.479980

# %%
plt.figure(figsize=(18,8))
plt.plot(index_SP500['Date'], index_SP500['Open'], color = 'r', label='Open')
plt.plot(index_SP500['Date'], index_SP500['Close'], color = 'b',label='Close')
plt.plot(index_SP500['Date'], index_SP500['High'], color = 'y',label='High')
plt.plot(index_SP500['Date'], index_SP500['Low'], color = 'g',label='Low')
plt.title('S&P 500 (^GSPC)')
plt.legend(loc='upper left')
plt.show()
